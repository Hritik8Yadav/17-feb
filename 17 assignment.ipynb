# %% [markdown]
# ![Q1.jpg](attachment:1d5f6ba2-136d-478a-b078-9fec58eea4ae.jpg)

# %%
#Ans1: MongoDB is a open sourse non relational database which stores data in the form of documents. It is a dynamic database.
# Non-relational databases are the one which doesnot have table schema instead they use other form to store the data.
# MongoDB can be used where the data is simple and not very large in size and storing and retrevial of data is need to be fast.

# %% [markdown]
# ![Q2.jpg](attachment:2dd401f9-d222-4a65-9d9a-1a9236717b3a.jpg)

# %%
#Ans2: 

# (i). Documentation: The data in MongoDB is stored in the BSON format which make it different from sql and the data 
#                     remains in a single file rather then multipile files.
# (ii). Indexing: In MOngoDB the data can easily retrived through Indexing this make the retrival of the data fast.
# (iii). Scalability: The MongoDB database can easily scalable through adding the new server, databases.

# %% [markdown]
# ![Q3.jpg](attachment:3c88036f-ebc2-4040-9b99-0a96e40fd1ad.jpg)

# %%
#Ans 3: 
import pymongo
client = pymongo.MongoClient("mongodb+srv://hritik:hritik@cluster0.3w8072c.mongodb.net/?retryWrites=true&w=majority")
db = client.test
data=client['New_database']
collect=data['New_collection']

# %%
# check
print(client.list_database_names())
# Out:
# ['New_database', 'test', 'admin', 'local']

# %% [markdown]
# ![Q4.jpg](attachment:f6c1d3c8-f8cd-44d4-b326-ce80758a1462.jpg)

# %%
#Ans 4: 
single_data={'Name':'hritik','Assignment':'Mongodb','date':'20/02/2023'}
collect.insert_one(single_data)
multi_data=[{'Name':'hritik','Assignment':'Mongodb','date':'20/02/2023'},
            {'Name':'hritik','Assignment':'sql','date':'19/02/2023'},
            {'Name':'hritik','Assignment':'multiprocessing','date':'18/02/2023'}]
collect.insert_many(multi_data)

# %%
print("This is single data: ",end=' ')
print(collect.find_one(single_data))
# Out:
# This is single data:  {'_id': ObjectId('63f39a3658bf447d9fe12623'), 'Name': 'hritik', 'Assignment': 'Mongodb', 'date': '20/02/2023'}
# This is multi data:
# {'_id': ObjectId('63f3978758bf447d9fe12622'), 'Name': 'hritik', 'Assignment': 'Mongodb', 'Date': '20/01/2023'}
# {'_id': ObjectId('63f39a3658bf447d9fe12623'), 'Name': 'hritik', 'Assignment': 'Mongodb', 'date': '20/02/2023'}
# {'_id': ObjectId('63f39a3658bf447d9fe12624'), 'Name': 'hritik', 'Assignment': 'Mongodb', 'date': '20/02/2023'}
# {'_id': ObjectId('63f39a3658bf447d9fe12625'), 'Name': 'hritik', 'Assignment': 'sql', 'date': '19/02/2023'}
# {'_id': ObjectId('63f39a3658bf447d9fe12626'), 'Name': 'hritik', 'Assignment': 'multiprocessing', 'date': '18/02/2023'}
# [None, None, None, None, None]

# %%
for i in collect.find():
    print(i)
# Out:
# {'_id': ObjectId('63f3978758bf447d9fe12622'), 'Name': 'hritik', 'Assignment': 'Mongodb', 'Date': '20/01/2023'}
# {'_id': ObjectId('63f39a3658bf447d9fe12623'), 'Name': 'hritik', 'Assignment': 'Mongodb', 'date': '20/02/2023'}
# {'_id': ObjectId('63f39a3658bf447d9fe12624'), 'Name': 'hritik', 'Assignment': 'Mongodb', 'date': '20/02/2023'}
# {'_id': ObjectId('63f39a3658bf447d9fe12625'), 'Name': 'hritik', 'Assignment': 'sql', 'date': '19/02/2023'}
# {'_id': ObjectId('63f39a3658bf447d9fe12626'), 'Name': 'hritik', 'Assignment': 'multiprocessing', 'date': '18/02/2023'}

# %% [markdown]
# ![Q5.jpg](attachment:4ef09237-0cda-4734-a95c-3a811aa19ff8.jpg)

# %%
print("This is multi data: ")
[print(i) for i in collect.find({'Name':'hritik'})]
# Out:
# This is multi data:
# {'_id': ObjectId('63f3978758bf447d9fe12622'), 'Name': 'hritik', 'Assignment': 'Mongodb', 'Date': '20/01/2023'}
# {'_id': ObjectId('63f39a3658bf447d9fe12623'), 'Name': 'hritik', 'Assignment': 'Mongodb', 'date': '20/02/2023'}
# {'_id': ObjectId('63f39a3658bf447d9fe12624'), 'Name': 'hritik', 'Assignment': 'Mongodb', 'date': '20/02/2023'}
# {'_id': ObjectId('63f39a3658bf447d9fe12625'), 'Name': 'hritik', 'Assignment': 'sql', 'date': '19/02/2023'}
# {'_id': ObjectId('63f39a3658bf447d9fe12626'), 'Name': 'hritik', 'Assignment': 'multiprocessing', 'date': '18/02/2023'}
# [None, None, None, None, None]

# %% [markdown]
# ![Q6.jpg](attachment:dee01330-64aa-4ea5-9fe1-95d0a678cd26.jpg)

# %%
#Ans6: The sort method is used to sort the data according to the asscending or descending order of the given key in the data.
# for example:-
d1=collect.find().sort('date')
for i in d1:
    print(i)
# Out:
# {'_id': ObjectId('63f3978758bf447d9fe12622'), 'Name': 'hritik', 'Assignment': 'Mongodb', 'Date': '20/01/2023'}
# {'_id': ObjectId('63f39a3658bf447d9fe12626'), 'Name': 'hritik', 'Assignment': 'multiprocessing', 'date': '18/02/2023'}
# {'_id': ObjectId('63f39a3658bf447d9fe12625'), 'Name': 'hritik', 'Assignment': 'sql', 'date': '19/02/2023'}
# {'_id': ObjectId('63f39a3658bf447d9fe12623'), 'Name': 'hritik', 'Assignment': 'Mongodb', 'date': '20/02/2023'}
# {'_id': ObjectId('63f39a3658bf447d9fe12624'), 'Name': 'hritik', 'Assignment': 'Mongodb', 'date': '20/02/2023'}

# %% [markdown]
# ![Q7.jZpg](attachment:01b19ba1-2952-42b2-aa85-1fb959e15be0.jpg)

# %%
#Ans1: delete_one() is used to delete a single instance of a data from the dataset which is not desired.
# delete_many() is used to delete more then one instance of a data from the dataset according to the expressing given to the method.
# drop() is used to delete entire collection form a database.
